# %%
import pandas as pd


#KDE with Seaborn
import seaborn as sns

# %%
#Load in csv file of 2004-2005 

#Change to Set1 = ('location of 2004-2005 set')

Set1 = pd.read_csv('C:/Users/demet/Downloads/OneDrive_1_10-23-2023/Solar_flare_RHESSI_2004_05.csv')

# %%
Set1.columns = Set1.columns.str.replace('.', '_')
# Out:
# C:\Users\demet\AppData\Local\Temp\ipykernel_5004\3935052685.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Set1.columns = Set1.columns.str.replace('.', '_')

# %%
Set1
# Out:
#        duration_s  peak_c/s  total_counts energy_kev  x_pos_asec  y_pos_asec  \
# 0             196       592      644352.0       6-12        -966        -207
# 1             588       592     1838208.0       6-12        -967        -200
# 2             712      1456     2815104.0      12-25         964         172
# 3            1096      3824    12128496.0      12-25        -972        -137
# 4             452       200      476352.0       6-12        -978        -249
# ...           ...       ...           ...        ...         ...         ...
# 17501         704        24       72312.0       6-12        -279         229
# 17502         212        22       24624.0       6-12        -402         238
# 17503         584       184      332976.0       6-12        -251         243
# 17504         512        56      101424.0       6-12        -250         228
# 17505         292        18       25416.0       6-12         879        -216
#
# ...

# %%
#Subdividing Set 1 into smaller batches

Set1Batch1 = Set1.values[0:3662] #1 - 4
Set1Batch2 = Set1.values[2003:4987] # 3 - 6
Set1Batch3 = Set1.values[3662: 7058] # 5 - 8
Set1Batch4 = Set1.values[4987: 8664] # 7 - 10
Set1Batch5 = Set1.values[7058: 10200] # 9 - 12
Set1Batch6 = Set1.values[8664: 11681] # 11 - 14
Set1Batch7 = Set1.values[10200: 12659] # 13 - 16
Set1Batch8 = Set1.values[11681: 13747] # 15 - 18
Set1Batch9 = Set1.values[12659:15542] # 17 - 20
Set1Batch10 = Set1.values[13747: 16453] # 19 - 22
Set1Batch11 = Set1.values[15542: 17506] # 21 - 24

# %%
#Method 1 using Seaborn for the intensity based on total.counts (I used 2:3 to get that column)

#bw_method = 10, I believe this is the best graph we can get

#1 + 2 + 3 + 4

sns.kdeplot(Set1Batch1[:, 2:3], bw_method = 10, fill = True)
# Out:
# <Axes: ylabel='Density'>

# %%
#Method 1 using Seaborn for 21 + 22 + 23 + 24

sns.kdeplot(Set1Batch11[:, 2:3], bw_method = 10, fill = True)
# Out:
# <Axes: ylabel='Density'>

# %%
Set1Batch1[:, 3:4]
# Out:
# array([['6-12'],
#        ['6-12'],
#        ['12-25'],
#        ...,
#        ['6-12'],
#        ['6-12'],
#        ['6-12']], dtype=object)
